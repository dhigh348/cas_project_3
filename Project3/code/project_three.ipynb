# %%
from google.colab import drive
drive.mount('/content/drive')
import os 
os.chdir('/content/drive/My Drive/Project3/code')
os.getcwd()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# '/content/drive/My Drive/Project3/code'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '../data/'

# %% [markdown]
# # Economy data loading and graphing functions

# %%
import pandas as pd
import numpy as np 

class Economy:

    def __init__(self, start_date, end_date, path):
        self.start_date = start_date
        self.end_date = end_date
        self.data = pd.read_csv(path)

    def filter_unemp_data(self, col_name, duration):
        date_data = self.data['DATE'].to_numpy()
        
        # date data
        for i, day in enumerate(date_data):
            if day == self.start_date:
                break

        # new dataframe data
        filtered_data = {'date': self.data['DATE'].iloc[i:i+duration], 
                         col_name.lower(): self.data[col_name].iloc[i:i+duration]}
        
        # new dataframe to return
        df = pd.DataFrame(filtered_data)
        df.set_index('date', inplace=True)
        return df
    
    def make_graph(self, data, xlabel, ylabel, title, labels, path):
        plt.figure(figsize=(10, 6))
        plt.plot(data)
        plt.xlabel(xlabel, fontsize=14)
        plt.ylabel(ylabel, fontsize=14)
        plt.title(title, fontsize=16)
        plt.xticks(rotation=25)
        plt.legend(labels)
        plt.savefig(path)

# %% [markdown]
# # running the local economy data for california during the wildfires

# %%
cali_unemp = Economy('2018-04-01', '2019-04-01', path+'ca_unemp.csv')
filtered_data_ca = cali_unemp.filter_unemp_data('CAUR', 12)
cali_unemp.make_graph(filtered_data_ca, 
                      'month',
                      'unemployment data', 
                      'Unemployment data during California wildfire year of 2018',
                      ['CA unemployment'],
                      path+'figures/ca_unemp.png')

# %%
filtered_data_ca
# Out:
#             caur
# date
# 2018-04-01   4.3
# 2018-05-01   4.3
# 2018-06-01   4.2
# 2018-07-01   4.2
# 2018-08-01   4.2
# 2018-09-01   4.2
# 2018-10-01   4.2
# 2018-11-01   4.2
# 2018-12-01   4.3
# 2019-01-01   4.3
# 2019-02-01   4.3
# 2019-03-01   4.2

# %% [markdown]
# # running the local economy for hurricane Katrina

# %%
la_unemp = Economy('2005-05-01', '2006-05-01', path+'la_unemp.csv')

# %%
filtered_data_la = la_unemp.filter_unemp_data('LAUR', 12)

# %%
la_unemp.make_graph(filtered_data_la,
                    'month', 
                    'unemployment rate',
                    'Unemployment rate over Hurricane Katrina year',
                    ['LA unemployment'],
                    path+'figures/la_unemp.png')

# %% [markdown]
# # us unemployment during katrina, california, and recession

# %%
us_unemp = Economy('2005-05-01', '2006-05-01', path+'us_unemp.csv')
filtered_data_us = us_unemp.filter_unemp_data('UNRATE', 12)
us_unemp.make_graph(filtered_data_us,
                    'month', 
                    'unemployment rate',
                    'US unemployment rate', 
                    ['US unemployment'],
                    path+'figures/us_unemp.png')

# %%
us_unemp.make_graph(filtered_data_us.append(filtered_data_la),
                    'month', 
                    'unemployment rates', 
                    'US and Louisiana unemployment rates', 
                    ['LA unemployment', 'US unemployment'],
                    path+'figures/us_la_unemp.png')

# %%
us_cali_unemp = Economy('2018-04-01', '2019-04-01', path+'us_unemp.csv')
filtered_data_us = us_cali_unemp.filter_unemp_data('UNRATE', 12)

us_cali_unemp.make_graph(filtered_data_us.append(filtered_data_ca), 
                         'month', 
                         'unemployment rates',
                         'US and California unemployment rates',
                         ['US unemployment', 'CA unemployment'],
                         path+'figures/ca_us_unemp.png')

# %%
filtered_data_us.describe()
# Out:
#           unrate
# count  12.000000
# mean    3.841667
# std     0.108362
# min     3.700000
# 25%     3.800000
# 50%     3.800000
# 75%     3.925000
# max     4.000000

# %%
recession_unemp = Economy('2008-09-01', '', path+'us_unemp.csv')
filtered_rec = recession_unemp.filter_unemp_data('UNRATE', 28)
recession_unemp.make_graph(filtered_rec,
                           'month',
                           'unemployment rate', 
                           'Recession unemployment rates',
                           ['recession unemployment'], 
                           path+'figures/recession_unemp.png')

# %%
covid_unemp = Economy('2019-05-01', '', path+'us_unemp.csv')
covid_filter = covid_unemp.filter_unemp_data('UNRATE', 12)
covid_unemp.make_graph(covid_filter, 
                       'month', 
                       'unemployment rate',
                       'Unemployment rates during Covid-19 pandemic',
                       ['covid-19 unemployment'],
                       path+'figures/cov_unemp.png')

# %%
covid_filter
# Out:
#             unrate
# date
# 2019-05-01     3.6
# 2019-06-01     3.7
# 2019-07-01     3.7
# 2019-08-01     3.7
# 2019-09-01     3.5
# 2019-10-01     3.6
# 2019-11-01     3.5
# 2019-12-01     3.5
# 2020-01-01     3.6
# 2020-02-01     3.5
# 2020-03-01     4.4
# 2020-04-01    14.7

# %% [markdown]
# # Stock data

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/c2/31/8b374a12b90def92a4e27d0fc595fc43635f395984e36a075244d98bd265/yfinance-0.1.54.tar.gz
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.0.3)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.18.4)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.6/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.12.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=430caec8561736601d20ae73e1e362a3804267680a9516628cf11f3a7f7cb37e
#   Stored in directory: /root/.cache/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# Installing collected packages: yfinance
# Successfully installed yfinance-0.1.54

# %% [markdown]
# This class is a container for the stock data that is being loaded with the specific time series. There is normalized data and functionality for plotting the data.

# %%
import yfinance as yf
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# Comparing stocks at a local level
class StockData:

    # initializing the class
    def __init__(self, stock_list, start_date, end_date):
        self.stock_list = stock_list
        self.start_date = start_date
        self.end_date = end_date

    # getting data from the stock
    def get_data(self):
        stock_ticker = yf.Tickers(' '.join([stock for (stock,_) in self.stock_list]))
        self.data = stock_ticker.history(
            interval='1d', 
            start=self.start_date, 
            end=self.end_date)['Close']
        self.data.rename(
            columns={ stock.upper(): name for (stock, name) in self.stock_list }, 
            inplace=True)

    # normalizing the data from the stocks
    def normalize_data(self):
        self.norm_data = pd.DataFrame()
        for (_, name) in self.stock_list:
            min_val = self.data[name].min(axis=0)
            max_val = self.data[name].max(axis=0)
            numerator = self.data[name] - min_val
            denominator = max_val - min_val
            # numerator = self.data[name] - self.data[name].mean(axis=0)
            # denominator = self.data[name].std(axis=0)
            self.norm_data[name] = numerator / denominator

    # visual representation of the data
    def plot_data(self, mean, title, labels, fig_path):
        plt.figure(figsize=(10, 6))
        if mean:
            plt.plot(self.norm_data.mean(axis=1))
            title = title + '_mean'
        else:
            plt.plot(self.norm_data)
        plt.xlabel('Date')
        plt.ylabel('Normalized Stock price')
        plt.title(title)
        plt.legend(loc=(1.04, 0), labels=labels)
        plt.savefig(fig_path)

# %% [markdown]
# The following is the gathering of all data within the specified time periods for each of the designated events. The events are Hurricane Katrina, the California wildfires of 2018, the recession of 2008 and our current Covid-19 situation. The data is gather and the appropriate plots are created for each of the timeframes.

# %%
# controller
def timeframe_stock_data(timeframes):
    data = {}
    # making the data for each time frame 
    for name, [start, end] in timeframes.items():
        stocks = StockData(stock_list, start, end)
        stocks.get_data()
        stocks.normalize_data()
        stocks.plot_data(False, name, [n for (_, n) in stock_list], '../data/figures/'+name+'.png')
        stocks.plot_data(True, name, ['Mean'], '../data/figures/'+name+'_mean.png')
        data[name] = stocks
    return data

# list of the stocks from each sector to compare
stock_list = [
    ('aapl', 'apple'), 
    ('xom', 'exxon'), 
    ('shw', 'sherwinn williams'),
    ('lmt', 'lockheed martin'),
    ('amzn', 'amazon'),
    ('wmt', 'walmart'),
    ('jnj', 'johnson and johnson'),
    ('jpm', 'jp morgan'),
    ('cmcsa', 'comcast'),
    ('xel', 'excel energy'),
    ('spg', 'simon property group')
]

# running the main program
timeframes = {
    'California_Wildfires': ['2018-02-01', '2019-02-01'],
    'Hurricane_Katrina': ['2005-01-01', '2006-01-01'],
    'Recession': ['2008-04-01', '2009-04-01'],
    'Covid-19': ['2019-05-05', '2020-05-05']
}
    
# getting the data for the time frame
timeframe_data = timeframe_stock_data(timeframes)
# Out:
# [*********************100%***********************]  11 of 11 completed
# [*********************100%***********************]  11 of 11 completed
# [*********************100%***********************]  11 of 11 completed
# [*********************100%***********************]  11 of 11 completed

# %%
time_data = pd.DataFrame()
for name, data in timeframe_data.items():
    mean_data = data.norm_data.mean(axis=1).to_numpy()[:251]
    time_data[name] = mean_data
time_data = time_data.dropna()

# %%
time_data.head()
# Out:
#    California_Wildfires  Hurricane_Katrina  Recession  Covid-19
# 0              0.590865           0.392209   0.708254  0.477850
# 1              0.523801           0.339389   0.719538  0.449527
# 2              0.390989           0.327662   0.717809  0.441189
# 3              0.426669           0.338385   0.721033  0.440254
# 4              0.427766           0.341314   0.730283  0.453175

# %%
time_data_values = time_data.values

# %% [markdown]
# Measuring the cross entropy for each dataset against the other datasets

# %%
# making buckets for the data 
def make_probability_buckets(data):
    buckets = {}
    for point in data:
        if point not in buckets:
            buckets[point] = 1
        else:
            value = buckets.get(point)
            buckets[point] = value + 1

    length = len(data)
    for key, prob in buckets.items():
        buckets[key] = prob / length

    return buckets

# %%
# measuring the cross entropy of two datasets
def cross_entropy(data_one, data_two):
    data_one = data_transform(data_one)
    data_two = data_transform(data_two)
    m = -np.multiply(data_one, np.log2(data_two))
    return np.sum(m)

# %%
def data_transform(data):
    data = np.floor(data * 100).astype(int)
    buckets = make_probability_buckets(data)
    data = [buckets[point] for point in data]
    return data

# %%
def mutual_information(data_one, data_two):
    # transforming the data into its probabilities
    data_one_trans = data_transform(data_one)
    data_two_trans = data_transform(data_two)
    total = 0

    # go through each of the lists inputs 
    for point in data_one_trans:
        for point_two in data_two_trans:
        # getting the joint probabilities of the data
            joint_data = point * point_two
            point_two_conditional = point_two * point / point
            point_conditional = point * point_two / point_two
            total += joint_data - point_two_conditional - point_conditional
        # joint_data = data_transform(
        #     np.divide(np.multiply(data_one_trans, 
        #                         data_two_trans), 
        #             data_two_trans))
        # # running the log function on the probabilities
        # log_data = np.log2(
        #     np.divide(joint_data, 
        #             np.multiply(data_one_trans, 
        #                         data_two_trans)))
    
    return total

# %%
from sklearn.metrics import mutual_info_score

# %%
# covid data for comparison for modeling
data = time_data_values[:, 3]

# getting the cross entropy comparison of each value agains the other
for i in range(3):
    ent = cross_entropy(data, time_data_values[:, i])
    print(mutual_info_score(data, time_data_values[:, i]))
    print(f'({i}) = {ent}')
# Out:
# 5.5254529391317835
# (0) = 36.23059566235318
# 5.5254529391317835
# (1) = 33.8313637181726
# 5.5254529391317835
# (2) = 37.82851869059304

# %% [markdown]
# Plotting the full time data and plotting the comparison between the California wildfire data and the Covid-19 data

# %%
plt.figure(figsize=(10, 6))
plt.plot(time_data)
plt.xlabel('Day', fontsize=14)
plt.ylabel('Normalized Stock Data', fontsize=14)
plt.title('11 Sector average of stocks over event year', fontsize=18)
plt.legend(loc=(1.02, 0), labels=time_data.columns)
plt.savefig('../data/figures/11sector_comparison.png')

# %%
def plot_figure(data, cols, xlabel, ylabel, title, labels, path):
    plt.figure(figsize=(10, 6))
    plt.plot(data[cols])
    plt.xlabel(xlabel, fontsize=14)
    plt.ylabel(ylabel, fontsize=14)
    plt.title(title, fontsize=18)
    plt.legend(loc=(1.02, 0), labels=labels)
    plt.savefig(path)

# %%
plot_figure(
    time_data, 
    ['California_Wildfires', 'Covid-19'],
    'Day',
    'Normalized Stock Data', 
    '11 Sector average of stocks over event year',
    ['California wildfires', 'covid-19'],
    '../data/figures/covid_cali.png')

# %%
plot_figure(
    time_data,
    ['Hurricane_Katrina', 'Covid-19'],
    'Day',
    'Normalized Stock Data',
    '11 Sector Average of Stocks Over Event Year',
    ['Katrina', 'Covid-19'],
    '../data/figures/katrina_covid.png'
)

# %% [markdown]
# # Testing

# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
time_data = time_data.dropna()
time_data.head()
# Out:
#    California_Wildfires  Hurricane_Katrina  Recession  Covid-19
# 1              0.523801           0.339389   0.708254  0.449527
# 2              0.390989           0.327662   0.719538  0.441189
# 3              0.426669           0.338385   0.717809  0.440254
# 4              0.427766           0.341314   0.721033  0.453175
# 5              0.325062           0.360732   0.730283  0.413343

# %%
time_data_array = time_data.to_numpy()

# %% [markdown]
# Getting the Pearson correlation value to determine how closely related the values are to each other. This will be contained in a dataframe used to determine the model to use for prediction.

# %%
coef_data = pd.DataFrame(
    np.corrcoef(time_data_array.T), 
    index=list(time_data.columns),
    columns=list(time_data.columns)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-dfd05b40ca52> in <module>()
#       1 coef_data = pd.DataFrame(
# ----> 2     np.corrcoef(time_data_array.T),
#       3     index=list(time_data.columns),
#       4     columns=list(time_data.columns)
#       5 )
#
# NameError: name 'time_data_array' is not defined

# %%
coef_data.head()
# Out:
#                       California_Wildfires  ...  Covid-19
# California_Wildfires              1.000000  ...  0.676905
# Hurricane_Katrina                 0.313929  ...  0.174880
# Recession                        -0.472706  ... -0.146440
# Covid-19                          0.676905  ...  1.000000
#
# [4 rows x 4 columns]

# %% [markdown]
# In the above data we see that the strongest correlation to the Covid-19 data is the California wildfire data. A model based on California wildfire will be used to predict the Covid-19 future.
#
# Below we will create the model based on the California wildfires using a time series and Tensorflow.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import matplotlib as mpl 
mpl.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# Making a method for grouping the time series based on a window size.

# %%
tickers = yf.Tickers([stock for (stock, _) in stock_list])
data = tickers.history('23mo', interval='60m')['Close']
data = data.dropna()
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
data.info
# Out:
# <bound method DataFrame.info of                                  AAPL         AMZN  ...        XEL        XOM
# Datetime                                            ...
# 2018-06-07 15:30:00-04:00  193.440002  1688.170044  ...  42.720001  82.849998
# 2018-06-08 09:30:00-04:00  190.380005  1682.420044  ...  42.630001  83.190002
# 2018-06-08 10:30:00-04:00  190.750000  1686.865967  ...  42.584999  83.280998
# 2018-06-08 11:30:00-04:00  190.959595  1687.800049  ...  42.679901  83.209999
# 2018-06-08 12:30:00-04:00  191.350006  1686.678711  ...  42.625000  83.419998
# ...                               ...          ...  ...        ...        ...
# 2020-05-07 11:30:00-04:00  304.255188  2361.899902  ...  60.549999  44.946400
# 2020-05-07 12:30:00-04:00  303.880005  2360.612305  ...  60.735001  44.509399
# 2020-05-07 13:30:00-04:00  303.540009  2357.000000  ...  61.090000  44.349998
# 2020-05-07 14:30:00-04:00  303.350006  2357.302734  ...  60.430000  44.224998
# 2020-05-07 15:30:00-04:00  303.200012  2357.458252  ...  60.314999  44.169998
#
# [3338 rows x 11 columns]>

# %%
data.head()
# Out:
#                                  AAPL         AMZN  ...        XEL        XOM
# Datetime                                            ...
# 2018-06-07 15:30:00-04:00  193.440002  1688.170044  ...  42.720001  82.849998
# 2018-06-08 09:30:00-04:00  190.380005  1682.420044  ...  42.630001  83.190002
# 2018-06-08 10:30:00-04:00  190.750000  1686.865967  ...  42.584999  83.280998
# 2018-06-08 11:30:00-04:00  190.959595  1687.800049  ...  42.679901  83.209999
# 2018-06-08 12:30:00-04:00  191.350006  1686.678711  ...  42.625000  83.419998
#
# [5 rows x 11 columns]

# %%
data.plot()

# %%
dataset = data.values

# %%
dataset_min = np.min(dataset, axis=0)
dataset_max = np.max(dataset, axis=0)
dataset = (dataset - dataset_min) / (dataset_max - dataset_min)

# %%
dataset.shape
# Out:
# (3345, 11)

# %%
dataset_mean = np.mean(dataset, axis=1)
dataset_mean = np.reshape(dataset_mean, (dataset_mean.shape[0], 1))
print(dataset_mean.shape)
# Out:
# (3338, 1)

# %%
dataset = np.array([np.append(a, dataset_mean[i]) for i, a in enumerate(dataset)])

# %%
plt.plot(dataset)
plt.figure()
plt.plot(dataset[:, 11])

# %%
tf.random.set_seed(7)

# %% [markdown]
# Setting the size of the training and validation data and then proceeding to split the data for training purposes.

# %%
def split_data(dataset, target_data, start_index, end_index, window_size):
    data = []
    labels = []

    # going through the data and creating frames of windows for predictions
    end_index = end_index - window_size
    for i in range(start_index, end_index):
        # getting the window for the data 
        window = range(i, i + window_size)
        
        # adding the window sized data to our dataset
        data.append(dataset[window])

        # labels from the target data to predice from the window size
        labels.append(target_data[i + window_size])
    return np.array(data), np.array(labels)

# %%
train_size = int(len(dataset) * 0.8)
wind_size = 40

# %%
x_train, x_test = dataset[:train_size], dataset[train_size:]
y_train, y_test = dataset[:train_size, 11], dataset[train_size:, 11]

# %%
valid_size = int(len(x_train) * 0.8)

x_train, x_valid = x_train[:valid_size], x_train[valid_size:]
y_train, y_valid = y_train[:valid_size], y_train[valid_size:]

# %%
x_window_train, y_window_train = split_data(x_train, y_train, 0, x_train.shape[0], wind_size)
x_window_valid, y_window_valid = split_data(x_valid, y_valid, 0, x_valid.shape[0], wind_size)
x_window_test, y_window_test = split_data(x_test, y_test, 0, x_test.shape[0], wind_size)

# %%
print(x_window_train.shape)
print(x_window_valid.shape)
print(x_window_test.shape)
# Out:
# (2096, 40, 12)
# (494, 40, 12)
# (628, 40, 12)

# %% [markdown]
# Checking that the data was split properly and that the plot is matching.

# %%
def plot_model(dataset, target, prediction, window_size, title):
    labels = ['x values', 'actual', 'prediction']
    marker = ['.-', 'rx', 'go']

    plt.figure(figsize=(10, 6))
    plt.title(title)
    plt.plot(range(window_size), dataset[:, 11], marker[0], label=labels[0])
    plt.plot(window_size, target, marker[1], label=labels[1])
    if prediction is not None:
        plt.plot(window_size, prediction, marker[2], label=labels[2])
    plt.xlabel('data')
    plt.ylabel('y data')
    plt.legend()

# %%
plot_model(x_window_train[0], y_window_train[0], None, wind_size, 'Initial method test')

# %% [markdown]
# Training the model

# %%
BATCH_SIZE = 256
BUFFER_SIZE = 400

x_values = tf.data.Dataset.from_tensor_slices((x_window_train, y_window_train))
x_values = x_values.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

x_valid_data = tf.data.Dataset.from_tensor_slices((x_window_valid, y_window_valid))
x_valid_data = x_valid_data.batch(BATCH_SIZE).repeat()

x_test_data = tf.data.Dataset.from_tensor_slices((x_window_test, y_window_test))
x_test_data = x_test_data.batch(BATCH_SIZE).repeat()

# %%
for x, y in x_values.take(1):
    print(x)
# Out:
# tf.Tensor(
# [[[0.26070757 0.44687282 0.1498569  ... 0.11827958 0.90973583 0.40934624]
#   [0.25946535 0.4412724  0.14762974 ... 0.12203451 0.91558796 0.41073364]
#   [0.26011345 0.44448943 0.13522123 ... 0.11964503 0.9173613  0.40782611]
#   ...
#   [0.27790447 0.44296771 0.07126953 ... 0.12049847 0.93411959 0.41237572]
#   [0.27886581 0.44815587 0.08304181 ... 0.11930374 0.93083877 0.41529765]
#   [0.278909   0.44750071 0.08908682 ... 0.11623153 0.93544956 0.41704444]]
#
#  [[0.35274102 0.43453124 0.17499214 ... 0.15412185 0.87578834 0.44318063]
#   [0.35166083 0.43608131 0.20489971 ... 0.1645332  0.87515515 0.45244644]
#   [0.35198488 0.43081147 0.21603576 ... 0.17187234 0.87474371 0.45632585]
#   ...
#   [0.35754793 0.48864247 0.2087178  ... 0.19610866 0.86256428 0.45145713]
#   [0.35641376 0.48829985 0.20681519 ... 0.19064685 0.86300765 0.45115778]
#   [0.35392983 0.48697388 0.20108185 ... 0.18757478 0.86291903 0.44938349]]
#
#  [[0.26405618 0.42071988 0.20426348 ... 0.15412185 0.91133179 0.43703553]
#   [0.25930333 0.413645   0.21539929 ... 0.14012629 0.901401   0.43943496]
#   [0.25735896 0.4001805  0.22908049 ... 0.14558797 0.89324354 0.4385092 ]
#   ...
#   [0.35455848 0.42963672 0.22653509 ... 0.18040622 0.88173437 0.45376262]
#   [0.36010809 0.43732558 0.23448928 ... 0.18211297 0.88419934 0.45791744]
#   [0.3615987  0.44537044 0.24403439 ... 0.18040622 0.8802093  0.45897629]]
#
#  ...
#
#  [[0.40788553 0.47687339 0.23671644 ... 0.21215226 0.84660397 0.48564846]
#   [0.40205242 0.46918452 0.23321658 ... 0.21317642 0.85547079 0.49056266]
#   [0.39643539 0.47418887 0.22398994 ... 0.21317642 0.85618016 0.4891673 ]
#   ...
#   [0.41058662 0.50931959 0.29112326 ... 0.17938219 0.87994331 0.49541797]
#   [0.41247693 0.5102006  0.29748651 ... 0.18040622 0.88153927 0.49783496]
#   [0.41053207 0.51076657 0.29182309 ... 0.17835817 0.88189402 0.49647086]]
#
#  [[0.43273029 0.5719517  0.2713968  ... 0.21693121 0.94289765 0.52716545]
#   [0.42943566 0.56863234 0.26153369 ... 0.21829667 0.93474019 0.52329319]
#   [0.44218209 0.56771461 0.26248816 ... 0.21829667 0.93474019 0.52378938]
#   ...
#   [0.40822846 0.50459421 0.35634742 ... 0.17118961 0.95557728 0.53639988]
#   [0.40961868 0.50980909 0.36010191 ... 0.16658137 0.95655439 0.53762723]
#   [0.41123414 0.51265677 0.35730188 ... 0.17016559 0.96054267 0.53596264]]
#
#  [[0.40837161 0.34213158 0.1648108  ... 0.20464254 0.93371694 0.45679655]
#   [0.40739674 0.34716983 0.15017513 ... 0.19952216 0.9272921  0.45080365]
#   [0.39821773 0.32575716 0.13935732 ... 0.19542593 0.91948925 0.44248916]
#   ...
#   [0.40124172 0.39075646 0.26630601 ... 0.20976279 0.90938108 0.46612407]
#   [0.40005406 0.38389972 0.26662424 ... 0.21624849 0.90849448 0.46857058]
#   [0.40027007 0.37860021 0.25835183 ... 0.21420044 0.91026782 0.46709083]]], shape=(256, 40, 12), dtype=float64)

# %%
model = Sequential([
    LSTM(32),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer=tf.optimizers.RMSprop(0.006),
    loss='mae',
    metrics=['accuracy']
)

# %%
for xv, yv in x_values.take(1):
    print(model.predict(xv).shape)
# Out:
# WARNING:tensorflow:Layer lstm is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# (256, 1)

# %%
model.fit(
    x_values,
    epochs=250,
    steps_per_epoch=100,
    validation_data=x_valid_data,
    validation_steps=50
)
# Out:
# Epoch 1/250
# WARNING:tensorflow:Layer lstm_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 100/100 [==============================] - 1s 10ms/step - loss: 0.
250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0438 - val_accuracy: 0.0000e+00
# Epoch 86/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0553 - val_accuracy: 0.0000e+00
# Epoch 87/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0391 - val_accuracy: 0.0000e+00
# Epoch 88/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 89/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0687 - val_accuracy: 0.0000e+00
# Epoch 90/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0367 - val_accuracy: 0.0000e+00
# Epoch 91/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 92/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0418 - val_accuracy: 0.0000e+00
# Epoch 93/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0492 - val_accuracy: 0.0000e+00
# Epoch 94/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0387 - val_accuracy: 0.0000e+00
# Epoch 95/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 96/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0661 - val_accuracy: 0.0000e+00
# Epoch 97/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0658 - val_accuracy: 0.0000e+00
# Epoch 98/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0653 - val_accuracy: 0.0000e+00
# Epoch 99/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0409 - val_accuracy: 0.0000e+00
# Epoch 100/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0523 - val_accuracy: 0.0000e+00
# Epoch 101/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0631 - val_accuracy: 0.0000e+00
# Epoch 102/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0503 - val_accuracy: 0.0000e+00
# Epoch 103/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0605 - val_accuracy: 0.0000e+00
# Epoch 104/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 105/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0404 - val_accuracy: 0.0000e+00
# Epoch 106/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0354 - val_accuracy: 0.0000e+00
# Epoch 107/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0401 - val_accuracy: 0.0000e+00
# Epoch 108/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0399 - val_accuracy: 0.0000e+00
# Epoch 109/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0467 - val_accuracy: 0.0000e+00
# Epoch 110/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0619 - val_accuracy: 0.0000e+00
# Epoch 111/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0533 - val_accuracy: 0.0000e+00
# Epoch 112/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0434 - val_accuracy: 0.0000e+00
# Epoch 113/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.
250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0655 - val_accuracy: 0.0000e+00
# Epoch 142/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0640 - val_accuracy: 0.0000e+00
# Epoch 143/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0379 - val_accuracy: 0.0000e+00
# Epoch 144/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0632 - val_accuracy: 0.0000e+00
# Epoch 145/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0514 - val_accuracy: 0.0000e+00
# Epoch 146/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0624 - val_accuracy: 0.0000e+00
# Epoch 147/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0518 - val_accuracy: 0.0000e+00
# Epoch 148/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0422 - val_accuracy: 0.0000e+00
# Epoch 149/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0453 - val_accuracy: 0.0000e+00
# Epoch 150/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0394 - val_accuracy: 0.0000e+00
# Epoch 151/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0392 - val_accuracy: 0.0000e+00
# Epoch 152/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0417 - val_accuracy: 0.0000e+00
# Epoch 153/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0444 - val_accuracy: 0.0000e+00
# Epoch 154/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0564 - val_accuracy: 0.0000e+00
# Epoch 155/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0622 - val_accuracy: 0.0000e+00
# Epoch 156/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0475 - val_accuracy: 0.0000e+00
# Epoch 157/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0534 - val_accuracy: 0.0000e+00
# Epoch 158/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0514 - val_accuracy: 0.0000e+00
# Epoch 159/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0626 - val_accuracy: 0.0000e+00
# Epoch 160/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0387 - val_accuracy: 0.0000e+00
# Epoch 161/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0418 - val_accuracy: 0.0000e+00
# Epoch 162/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0426 - val_accuracy: 0.0000e+00
# Epoch 163/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0502 - val_accuracy: 0.0000e+00
# Epoch 164/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0644 - val_accuracy: 0.0000e+00
# Epoch 165/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0526 - val_accuracy: 0.0000e+00
# Epoch 166/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0433 - val_accuracy: 0.0000e+00
# Epoch 167/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0453 - val_accuracy: 0.0000e+00
# Epoch 168/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0383 - val_accuracy: 0.0000e+00
# Epoch 169/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0409 - val_accuracy: 0.0000e+00
# Epoch 170/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 171/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0617 - val_accuracy: 0.0000e+00
# Epoch 172/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0525 - val_accuracy: 0.0000e+00
# Epoch 173/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0621 - val_accuracy: 0.0000e+00
# Epoch 174/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0494 - val_accuracy: 0.0000e+00
# Epoch 175/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0439 - val_accuracy: 0.0000e+00
# Epoch 176/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0462 - val_accuracy: 0.0000e+00
# Epoch 177/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0383 - val_accuracy: 0.0000e+00
# Epoch 178/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0405 - val_accuracy: 0.0000e+00
# Epoch 179/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0419 - val_accuracy: 0.0000e+00
# Epoch 180/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0397 - val_accuracy: 0.0000e+00
# Epoch 181/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0515 - val_accuracy: 0.0000e+00
# Epoch 182/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0440 - val_accuracy: 0.0000e+00
# Epoch 183/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0607 - val_accuracy: 0.0000e+00
# Epoch 184/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0421 - val_accuracy: 0.0000e+00
# Epoch 185/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0476 - val_accuracy: 0.0000e+00
# Epoch 186/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0384 - val_accuracy: 0.0000e+00
# Epoch 187/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0660 - val_accuracy: 0.0000e+00
# Epoch 188/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0410 - val_accuracy: 0.0000e+00
# Epoch 189/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0467 - val_accuracy: 0.0000e+00
# Epoch 190/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0519 - val_accuracy: 0.0000e+00
# Epoch 191/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0421 - val_accuracy: 0.0000e+00
# Epoch 192/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0530 - val_accuracy: 0.0000e+00
# Epoch 193/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0401 - val_accuracy: 0.0000e+00
# Epoch 194/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0496 - val_accuracy: 0.0000e+00
# Epoch 195/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0394 - val_accuracy: 0.0000e+00
# Epoch 196/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0393 - val_accuracy: 0.0000e+00
# Epoch 197/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0622 - val_accuracy: 0.0000e+00
# Epoch 226/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 227/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0632 - val_accuracy: 0.0000e+00
# Epoch 228/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0537 - val_accuracy: 0.0000e+00
# Epoch 229/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0613 - val_accuracy: 0.0000e+00
# Epoch 230/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 231/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0675 - val_accuracy: 0.0000e+00
# Epoch 232/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 233/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0643 - val_accuracy: 0.0000e+00
# Epoch 234/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 235/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0510 - val_accuracy: 0.0000e+00
# Epoch 236/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0631 - val_accuracy: 0.0000e+00
# Epoch 237/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0543 - val_accuracy: 0.0000e+00
# Epoch 238/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0644 - val_accuracy: 0.0000e+00
# Epoch 239/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 240/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0641 - val_accuracy: 0.0000e+00
# Epoch 241/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0671 - val_accuracy: 0.0000e+00
# Epoch 242/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0655 - val_accuracy: 0.0000e+00
# Epoch 243/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0660 - val_accuracy: 0.0000e+00
# Epoch 244/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0544 - val_accuracy: 0.0000e+00
# Epoch 245/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0639 - val_accuracy: 0.0000e+00
# Epoch 246/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0566 - val_accuracy: 0.0000e+00
# Epoch 247/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0610 - val_accuracy: 0.0000e+00
# Epoch 248/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 249/250
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0664 - val_accuracy: 0.0000e+00
# Epoch 250/250
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0399 - val_accuracy: 0.0000e+00

# %%
import matplotlib.pyplot as plt
for xt, yt in x_test_data.take(5):
    plot_model(xt[0].numpy(), yt[0].numpy(), model.predict(xt)[0], wind_size, 'pred')
    plt.show()

# %% [markdown]
# calculating std dev
