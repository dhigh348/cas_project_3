# %%
from google.colab import drive
drive.mount('/content/drive')
import os 
os.chdir('/content/drive/My Drive/Project3/code')
os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/My Drive/Project3/code'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '../data/'

# %%
# list of the stocks from each sector to compare
stock_list = [
    ('aapl', 'apple'), 
    ('xom', 'exxon'), 
    ('shw', 'sherwinn williams'),
    ('lmt', 'lockheed martin'),
    ('amzn', 'amazon'),
    ('wmt', 'walmart'),
    ('jnj', 'johnson and johnson'),
    ('jpm', 'jp morgan'),
    ('cmcsa', 'comcast'),
    ('xel', 'excel energy'),
    ('spg', 'simon property group')
]

# %% [markdown]
# # Economy data loading and graphing functions

# %%
import pandas as pd
import numpy as np 

class Economy:

    def __init__(self, start_date, end_date, path):
        self.start_date = start_date
        self.end_date = end_date
        self.data = pd.read_csv(path)

    def filter_unemp_data(self, col_name, duration):
        date_data = self.data['DATE'].to_numpy()
        
        # date data
        for i, day in enumerate(date_data):
            if day == self.start_date:
                break

        # new dataframe data
        filtered_data = {'date': self.data['DATE'].iloc[i:i+duration], 
                         col_name.lower(): self.data[col_name].iloc[i:i+duration]}
        
        # new dataframe to return
        df = pd.DataFrame(filtered_data)
        df.set_index('date', inplace=True)
        return df
    
    def make_graph(self, data, xlabel, ylabel, title, labels, path):
        plt.figure(figsize=(10, 6))
        plt.plot(data)
        plt.xlabel(xlabel, fontsize=14)
        plt.ylabel(ylabel, fontsize=14)
        plt.title(title, fontsize=16)
        plt.xticks(rotation=25)
        plt.legend(labels)
        plt.savefig(path)

# %% [markdown]
# # running the local economy data for california during the wildfires

# %%
cali_unemp = Economy('2018-04-01', '2019-04-01', path+'ca_unemp.csv')
filtered_data_ca = cali_unemp.filter_unemp_data('CAUR', 12)
cali_unemp.make_graph(filtered_data_ca, 
                      'month',
                      'unemployment data', 
                      'Unemployment data during California wildfire year of 2018',
                      ['CA unemployment'],
                      path+'figures/ca_unemp.png')

# %%
filtered_data_ca
# Out:
#             caur
# date
# 2018-04-01   4.3
# 2018-05-01   4.3
# 2018-06-01   4.2
# 2018-07-01   4.2
# 2018-08-01   4.2
# 2018-09-01   4.2
# 2018-10-01   4.2
# 2018-11-01   4.2
# 2018-12-01   4.3
# 2019-01-01   4.3
# 2019-02-01   4.3
# 2019-03-01   4.2

# %% [markdown]
# # running the local economy for hurricane Katrina

# %%
la_unemp = Economy('2005-05-01', '2006-05-01', path+'la_unemp.csv')

# %%
filtered_data_la = la_unemp.filter_unemp_data('LAUR', 12)

# %%
la_unemp.make_graph(filtered_data_la,
                    'month', 
                    'unemployment rate',
                    'Unemployment rate over Hurricane Katrina year',
                    ['LA unemployment'],
                    path+'figures/la_unemp.png')

# %% [markdown]
# # us unemployment during katrina, california, and recession

# %%
us_unemp = Economy('2005-05-01', '2006-05-01', path+'us_unemp.csv')
filtered_data_us = us_unemp.filter_unemp_data('UNRATE', 12)
us_unemp.make_graph(filtered_data_us,
                    'month', 
                    'unemployment rate',
                    'US unemployment rate', 
                    ['US unemployment'],
                    path+'figures/us_unemp.png')

# %%
filtered_data_us.describe()
# Out:
#           unrate
# count  12.000000
# mean    4.900000
# std     0.141421
# min     4.700000
# 25%     4.775000
# 50%     4.950000
# 75%     5.000000
# max     5.100000

# %%
filtered_data_us.plot.box()

# %%
us_unemp.make_graph(filtered_data_us.append(filtered_data_la),
                    'month', 
                    'unemployment rates', 
                    'US and Louisiana unemployment rates', 
                    ['LA unemployment', 'US unemployment'],
                    path+'figures/us_la_unemp.png')

# %%
us_cali_unemp = Economy('2018-04-01', '2019-04-01', path+'us_unemp.csv')
filtered_data_us = us_cali_unemp.filter_unemp_data('UNRATE', 12)

us_cali_unemp.make_graph(filtered_data_us.append(filtered_data_ca), 
                         'month', 
                         'unemployment rates',
                         'US and California unemployment rates',
                         ['US unemployment', 'CA unemployment'],
                         path+'figures/ca_us_unemp.png')

# %%
filtered_data_us.describe()
# Out:
#           unrate
# count  12.000000
# mean    3.841667
# std     0.108362
# min     3.700000
# 25%     3.800000
# 50%     3.800000
# 75%     3.925000
# max     4.000000

# %%
recession_unemp = Economy('2008-09-01', '', path+'us_unemp.csv')
filtered_rec = recession_unemp.filter_unemp_data('UNRATE', 28)
recession_unemp.make_graph(filtered_rec,
                           'month',
                           'unemployment rate', 
                           'Recession unemployment rates',
                           ['recession unemployment'], 
                           path+'figures/recession_unemp.png')

# %%
covid_unemp = Economy('2019-05-01', '', path+'us_unemp.csv')
covid_filter = covid_unemp.filter_unemp_data('UNRATE', 12)
covid_unemp.make_graph(covid_filter, 
                       'month', 
                       'unemployment rate',
                       'Unemployment rates during Covid-19 pandemic',
                       ['covid-19 unemployment'],
                       path+'figures/cov_unemp.png')

# %%
covid_filter
# Out:
#             unrate
# date
# 2019-05-01     3.6
# 2019-06-01     3.7
# 2019-07-01     3.7
# 2019-08-01     3.7
# 2019-09-01     3.5
# 2019-10-01     3.6
# 2019-11-01     3.5
# 2019-12-01     3.5
# 2020-01-01     3.6
# 2020-02-01     3.5
# 2020-03-01     4.4
# 2020-04-01    14.7

# %% [markdown]
# # Stock data

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/c2/31/8b374a12b90def92a4e27d0fc595fc43635f395984e36a075244d98bd265/yfinance-0.1.54.tar.gz
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.0.3)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.18.4)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.6/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.12.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=d283476d3d3da8a331f5450b437f7fcfb14c18b31c3f9f75713a533ff7326b67
#   Stored in directory: /root/.cache/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# Installing collected packages: yfinance
# Successfully installed yfinance-0.1.54

# %% [markdown]
# This class is a container for the stock data that is being loaded with the specific time series. There is normalized data and functionality for plotting the data.

# %%
import yfinance as yf
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# Comparing stocks at a local level
class StockData:

    # initializing the class
    def __init__(self, stock_list, start_date, end_date):
        self.stock_list = stock_list
        self.start_date = start_date
        self.end_date = end_date

    # getting data from the stock
    def get_data(self):
        stock_ticker = yf.Tickers(' '.join([stock for (stock,_) in self.stock_list]))
        self.data = stock_ticker.history(
            interval='1d', 
            start=self.start_date, 
            end=self.end_date)['Close']
        self.data.rename(
            columns={ stock.upper(): name for (stock, name) in self.stock_list }, 
            inplace=True)

    # normalizing the data from the stocks
    def normalize_data(self):
        self.norm_data = pd.DataFrame()
        for (_, name) in self.stock_list:
            min_val = self.data[name].min(axis=0)
            max_val = self.data[name].max(axis=0)
            numerator = self.data[name] - min_val
            denominator = max_val - min_val
            # numerator = self.data[name] - self.data[name].mean(axis=0)
            # denominator = self.data[name].std(axis=0)
            self.norm_data[name] = numerator / denominator

    # visual representation of the data
    def plot_data(self, mean, title, labels, fig_path):
        plt.figure(figsize=(10, 6))
        if mean:
            plt.plot(self.norm_data.mean(axis=1))
            title = title + '_mean'
        else:
            plt.plot(self.norm_data)
        plt.xlabel('Date')
        plt.ylabel('Normalized Stock price')
        plt.title(title)
        plt.legend(loc=(1.04, 0), labels=labels)
        plt.savefig(fig_path)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# The following is the gathering of all data within the specified time periods for each of the designated events. The events are Hurricane Katrina, the California wildfires of 2018, the recession of 2008 and our current Covid-19 situation. The data is gather and the appropriate plots are created for each of the timeframes.

# %%
# controller
def timeframe_stock_data(timeframes):
    data = {}
    # making the data for each time frame 
    for name, [start, end] in timeframes.items():
        stocks = StockData(stock_list, start, end)
        stocks.get_data()
        stocks.normalize_data()
        stocks.plot_data(False, name, [n for (_, n) in stock_list], '../data/figures/'+name+'.png')
        stocks.plot_data(True, name, ['Mean'], '../data/figures/'+name+'_mean.png')
        data[name] = stocks
    return data

# running the main program
timeframes = {
    'California_Wildfires': ['2018-02-01', '2019-02-01'],
    'Hurricane_Katrina': ['2005-01-01', '2006-01-01'],
    'Recession': ['2008-04-01', '2009-04-01'],
    'Covid-19': ['2019-05-05', '2020-05-05']
}
    
# getting the data for the time frame
timeframe_data = timeframe_stock_data(timeframes)
# Out:
# [*********************100%***********************]  11 of 11 completed
# [*********************100%***********************]  11 of 11 completed
# [*********************100%***********************]  11 of 11 completed
# [*********************100%***********************]  11 of 11 completed

# %%
time_data = pd.DataFrame()
for name, data in timeframe_data.items():
    mean_data = data.norm_data.mean(axis=1).to_numpy()[:251]
    time_data[name] = mean_data
time_data = time_data.dropna()

# %%
time_data.head()
# Out:
#    California_Wildfires  Hurricane_Katrina  Recession  Covid-19
# 1              0.523801           0.339389   0.708254  0.449527
# 2              0.390989           0.327662   0.719538  0.441189
# 3              0.426669           0.338385   0.717809  0.440254
# 4              0.427766           0.341314   0.721033  0.453175
# 5              0.325062           0.360732   0.730283  0.413343

# %%
time_data_values = time_data.values

# %% [markdown]
# Measuring the cross entropy for each dataset against the other datasets

# %%
# making buckets for the data 
def make_probability_buckets(data):
    buckets = {}
    for point in data:
        if point not in buckets:
            buckets[point] = 1
        else:
            value = buckets.get(point)
            buckets[point] = value + 1

    length = len(data)
    for key, prob in buckets.items():
        buckets[key] = prob / length

    return buckets

# %%
# measuring the cross entropy of two datasets
def cross_entropy(data_one, data_two):
    data_one = data_transform(data_one)
    data_two = data_transform(data_two)
    m = -np.multiply(data_one, np.log2(data_two))
    return np.sum(m)

# %%
def data_transform(data):
    data = np.floor(data * 100).astype(int)
    buckets = make_probability_buckets(data)
    data = [buckets[point] for point in data]
    return data

# %%
def mutual_information(data_one, data_two):
    # transforming the data into its probabilities
    data_one_trans = data_transform(data_one)
    data_two_trans = data_transform(data_two)
    total = 0

    # go through each of the lists inputs 
    for point in data_one_trans:
        for point_two in data_two_trans:
        # getting the joint probabilities of the data
            joint_data = point * point_two
            point_two_conditional = point_two * point / point
            point_conditional = point * point_two / point_two
            total += joint_data - point_two_conditional - point_conditional
        # joint_data = data_transform(
        #     np.divide(np.multiply(data_one_trans, 
        #                         data_two_trans), 
        #             data_two_trans))
        # # running the log function on the probabilities
        # log_data = np.log2(
        #     np.divide(joint_data, 
        #             np.multiply(data_one_trans, 
        #                         data_two_trans)))
    
    return total

# %%
# covid data for comparison for modeling
data = time_data['Covid-19']
entropy_data = []

# getting the cross entropy comparison of each value agains the other
for col in time_data.columns[:-1]:
    ent = cross_entropy(data, time_data[col])
    entropy_data.append(ent)
    print(f'{col}: {ent}')
# Out:
# California_Wildfires: 36.21512523480422
# Hurricane_Katrina: 33.823156898568264
# Recession: 38.03590641987178

# %%
plt.figure(figsize=(10, 6))
plt.title('Entropy of Covid-19 and comparison timeline', fontsize=18)
plt.bar(time_data.columns[:-1], entropy_data)
plt.legend(['entropy compared with covid-19'])
plt.ylabel('bits of information', fontsize=14)
plt.savefig('../data/figures/cross_ent.png')

# %% [markdown]
# Plotting the full time data and plotting the comparison between the California wildfire data and the Covid-19 data

# %%
plt.figure(figsize=(10, 6))
plt.plot(time_data)
plt.xlabel('Day', fontsize=14)
plt.ylabel('Normalized Stock Data', fontsize=14)
plt.title('11 Sector average of stocks over event year', fontsize=18)
plt.legend(loc=(1.02, 0), labels=time_data.columns)
plt.savefig('../data/figures/11sector_comparison.png')

# %%
plt.figure(figsize=(10, 6))
plt.plot(time_data[['Hurricane_Katrina', 'Covid-19']])
plt.xlabel('Day', fontsize=14)
plt.ylabel('Normalized Stock Data', fontsize=14)
plt.title('11 Sector average of stocks over event year', fontsize=18)
plt.legend(loc=(1.02, 0), labels=['California_Wildfires', 'Covid-19'])
plt.savefig(path+'/figures/kat_covid_stock.png')

# %% [markdown]
# # Testing

# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
time_data = time_data.dropna()
time_data.head()
# Out:
#    California_Wildfires  Hurricane_Katrina  Recession  Covid-19
# 1              0.523801           0.339389   0.708254  0.449527
# 2              0.390989           0.327662   0.719538  0.441189
# 3              0.426669           0.338385   0.717809  0.440254
# 4              0.427766           0.341314   0.721033  0.453175
# 5              0.325062           0.360732   0.730283  0.413343

# %%
time_data_array = time_data.to_numpy()

# %% [markdown]
# Getting the Pearson correlation value to determine how closely related the values are to each other. This will be contained in a dataframe used to determine the model to use for prediction.

# %%
coef_data = pd.DataFrame(
    np.corrcoef(time_data_array.T), 
    index=list(time_data.columns),
    columns=list(time_data.columns)
)

# %%
coef_data.head()

# %% [markdown]
# # performing the tensorflow portion of modeling

# %% [markdown]
# In the above data we see that the strongest correlation to the Covid-19 data is the California wildfire data. A model based on California wildfire will be used to predict the Covid-19 future.
#
# Below we will create the model based on the California wildfires using a time series and Tensorflow.

# %%
import yfinance as yf
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import matplotlib as mpl 
mpl.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# Making a method for grouping the time series based on a window size.

# %%
tickers = yf.Tickers([stock for (stock, _) in stock_list])
data = tickers.history('1y', start='2005-01-01', end='2006-01-01', interval='1d')['Close']
data = data.dropna()
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
data.plot()

# %% [markdown]
# Normalizing the data to ensure that each stock's data is in the workable range and that no stock influences the results more than another.

# %%
def normalize(data):
    data_min = np.min(data, axis=0)
    data_max = np.max(data, axis=0)
    return (data - data_min) / (data_max - data_min)

# %%
dataset = data.values

# %%
dataset = np.mean(normalize(dataset), axis=1).reshape(dataset.shape[0], 1)

# %%
dataset.shape
# Out:
# (252, 1)

# %%
plt.plot(dataset)

# %%
tf.random.set_seed(7)

# %% [markdown]
# ## Setting the size of the training and validation data and then proceeding to split the data for training purposes.

# %%
def split_data(dataset, target_data, start_index, end_index, window_size):
    data = []
    labels = []

    # going through the data and creating frames of windows for predictions
    end_index = end_index - window_size
    for i in range(start_index, end_index):
        # getting the window for the data 
        window = range(i, i + window_size)
        
        # adding the window sized data to our dataset
        data.append(np.reshape(dataset[window], (wind_size, 1)))

        # labels from the target data to predice from the window size
        labels.append(dataset[i + window_size])
    return np.array(data), np.array(labels)

# %%
train_size = int(len(dataset) * 0.8)
wind_size = 5

# %%
y_train = dataset[wind_size:]

# %%
x_train, y_train = split_data(dataset, 
                              y_train, 
                              0,
                              dataset.shape[0], 
                              wind_size)

# %%
print(x_train[0:3])
print(y_train[:2])
# Out:
# [[[0.3922088 ]
#   [0.33938896]
#   [0.32766208]
#   [0.33838465]
#   [0.34131376]]
#
#  [[0.33938896]
#   [0.32766208]
#   [0.33838465]
#   [0.34131376]
#   [0.36073202]]
#
#  [[0.32766208]
#   [0.33838465]
#   [0.34131376]
#   [0.36073202]
#   [0.34380305]]]
# [[0.36073202]
#  [0.34380305]]

# %% [markdown]
# # Normalizing the data for the covid timeline

# %%
data_test = tickers.history('1y', start='2019-05-01', end='2020-05-01', interval='1d')['Close']
data_test = data_test.dropna()
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
data_test_norm = data_test.values
data_test_norm = np.mean(normalize(data_test_norm), axis=1).reshape(data_test_norm.shape[0], 1)

# %%
x_test_data, y_test_data = split_data(
    data_test_norm,
    data_test_norm[wind_size:],
    0, 
    data_test_norm.shape[0],
    wind_size
)

# %% [markdown]
# Checking that the data was split properly and that the plot is matching.

# %%
def plot_model(dataset, target, prediction, window_size, title):
    labels = ['x values', 'actual', 'prediction']
    marker = ['.-', 'rx', 'go']

    plt.figure(figsize=(10, 6))
    plt.title(title)
    plt.plot(range(window_size), dataset, marker[0], label=labels[0])
    plt.plot(window_size, target, marker[1], label=labels[1])
    if prediction is not None:
        plt.plot(window_size, prediction, marker[2], label=labels[2])
    plt.xlabel('data')
    plt.ylabel('y data')
    plt.legend()

# %%
plot_model(x_train[0], y_train[0], None, wind_size, 'Initial method test')

# %% [markdown]
# Training the model

# %%
BATCH_SIZE = 128
BUFFER_SIZE = 4

x_values = tf.data.Dataset.from_tensor_slices((x_train, y_train))
x_values = x_values.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

x_test = tf.data.Dataset.from_tensor_slices((x_test_data, y_test_data))
x_test = x_test.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

# %%
print(x_train)
# Out:
# [[[0.3922088 ]
#   [0.33938896]
#   [0.32766208]
#   [0.33838465]
#   [0.34131376]]
#
#  [[0.33938896]
#   [0.32766208]
#   [0.33838465]
#   [0.34131376]
#   [0.36073202]]
#
#  [[0.32766208]
#   [0.33838465]
#   [0.34131376]
#   [0.36073202]
#   [0.34380305]]
#
#  ...
#
#  [[0.63559581]
#   [0.64710348]
#   [0.67593049]
#   [0.67407443]
#   [0.65226464]]
#
#  [[0.64710348]
#   [0.67593049]
#   [0.67407443]
#   [0.65226464]
#   [0.65494314]]
#
#  [[0.67593049]
#   [0.67407443]
#   [0.65226464]
#   [0.65494314]
#   [0.63469796]]]

# %%
model = Sequential([
    LSTM(8, input_shape=x_train.shape[-2:]),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer=tf.optimizers.RMSprop(0.001),
    loss='mae',
    metrics=['accuracy']
)

# %%
for x, y in x_values.take(1):
    print(model.predict(x).shape)
# Out:
# (128, 1)

# %%
model.fit(
    x_values,
    epochs=250,
    steps_per_epoch=100
)
# Out:
# Train for 100 steps
# Epoch 1/250
# 100/100 [==============================] - 1s 15ms/step - loss: 0.1025 - accuracy: 0.0000e+00
# Epoch 2/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.0000e+00
# Epoch 3/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.0000e+00
# Epoch 4/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.0000e+00
# Epoch 5/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.0000e+00
# Epoch 6/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.0000e+00
# Epoch 7/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 0.0000e+00
# Epoch 8/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.0000e+00
# Epoch 9/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.0000e+00
# Epoch 10/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.0000e+00
# Epoch 11/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.0000e+00
# Epoch 12/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.0000e+00
# Epoch 13/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 0.0000e+00
# Epoch 14/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.0000e+00
# Epoch 15/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 0.0000e+00
# Epoch 16/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 0.0000e+00
# Epoch 17/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.0000e+00
# Epoch 18/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 0.0000e+00
# Epoch 19/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.0000e+00
# Epoch 20/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.0000e+00
# Epoch 21/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.0000e+00
# Epoch 22/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 0.0000e+00
# Epoch 23/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 0.0000e+00
# Epoch 24/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.0000e+00
# Epoch 25/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 0.0000e+00
# Epoch 26/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 0.0000e+00
# Epoch 27/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 0.0000e+00
# Epoch 28/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.0000e+00
# Epoch 29/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0227 - accuracy: 0.0000e+00
# Epoch 30/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.0000e+00
# Epoch 31/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.0000e+00
# Epoch 32/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.0000e+00
# Epoch 33/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 34/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.0000e+00
# Epoch 35/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.0000e+00
# Epoch 36/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.0000e+00
# Epoch 37/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.0000e+00
# Epoch 38/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 39/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 40/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 41/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 42/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 43/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 44/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 45/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 46/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 47/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 48/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 0.0000e+00
# Epoch 49/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 50/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 51/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 52/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 53/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 54/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 55/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 56/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 57/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 58/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.0000e+00
# Epoch 59/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 60/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 61/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 62/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 63/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 64/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 65/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.0000e+00
# Epoch 66/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 67/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 68/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.0000e+00
# Epoch 69/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.0000e+00
# Epoch 70/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 71/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.0000e+00
# Epoch 72/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.0000e+00
# Epoch 73/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 74/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.0000e+00
# Epoch 75/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 76/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 77/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.0000e+00
# Epoch 78/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 79/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 80/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 81/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 82/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 83/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.0000e+00
# Epoch 84/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 85/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 86/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 87/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 88/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 89/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 90/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 91/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 92/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 93/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 94/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 95/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 96/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 97/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 98/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 99/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 100/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 101/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 102/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 103/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 104/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 105/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 106/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 107/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 108/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 109/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 110/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 111/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 112/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 113/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 114/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.0000e+00
# Epoch 115/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 116/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 117/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 118/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 119/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 120/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 121/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 122/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 123/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 124/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 125/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 126/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 127/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 128/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 129/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 130/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 131/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 132/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 133/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 134/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 135/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 136/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 137/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 0.0000e+00
# Epoch 138/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 139/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 140/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 141/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 142/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 143/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 144/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 145/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 146/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 147/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 148/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 149/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.0000e+00
# Epoch 150/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 151/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 152/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 153/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 154/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 155/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 156/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 157/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 158/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 159/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 160/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 161/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.0000e+00
# Epoch 162/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 163/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 164/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 165/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 166/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 167/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 168/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 169/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 170/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 171/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 172/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 173/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 174/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 175/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 176/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 177/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 178/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 179/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 180/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 181/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 182/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 183/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 184/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 185/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 186/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 187/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 188/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 189/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 190/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 191/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 192/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 193/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 194/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 195/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 196/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.0000e+00
# Epoch 197/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 198/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 199/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 200/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 201/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 202/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 203/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 204/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 205/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 206/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 207/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 208/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 209/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 210/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.0000e+00
# Epoch 211/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 212/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 213/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 214/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 215/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 216/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 217/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 218/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 219/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 220/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 221/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 222/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 223/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 224/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 225/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 226/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 227/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 228/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 229/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.0000e+00
# Epoch 230/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 231/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 232/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 233/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 234/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 235/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 236/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 237/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 238/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 239/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 240/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 241/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 242/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 243/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 244/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 245/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 246/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 247/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 248/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 249/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 250/250
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.0000e+00

# %%
import matplotlib.pyplot as plt
for xt, yt in x_test.take(5):
    plot_model(xt[0].numpy(), yt[0].numpy(), model.predict(xt)[0], wind_size, 'pred')
    plt.show()
